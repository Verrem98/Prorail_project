# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as pl
import seaborn as sns

# %% [markdown]
# ### Storingstijden Voorspellen door een Ml model te trainen op prorail data.
#
#
# Doel
#
#
# A. Business Understanding
#
# B. Data Understanding
#
# C. Data peparation
#
# D. Modeling
#
# E. Evaluation
#
# F.Deployment

# %%
df = pd.read_csv('sap_storing_data_hu_project.csv')
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
df.shape
# Out:
# (898526, 140)

# %%
df.head()
# Out:
#   Unnamed: 0  #stm_sap_meldnr  stm_mon_nr stm_vl_post     stm_sap_meld_ddt  \
# 0          0                0         NaN         NaN                  NaN
# 1          1         50053211         0.0         NaN  02/01/2006 09:00:00
# 2          2         50053213        48.0          GN  02/01/2006 12:35:00
# 3          3         50053214        72.0          ZL  02/01/2006 16:40:00
# 4          4         50053215        96.0          ZL  02/01/2006 22:30:00
#
#   stm_sap_mon_meld_ddt                             stm_sap_meldtekst_lang  \
# 0                  NaN                                                NaN
# 1  02/01/2006 09:00:00   Logboeknr  Geeltje  :   49 Tijd: 0900   VL-Po...
# 2  02/01/2006 12:35:00   Logboeknr  RBV  :   48 Tijd: 1235   VL-Post: ...
# 3  02/01/2006 16:40:00   Logboeknr  RBV  :   72 Tijd: 1640   VL-Post: ...
# 4  02/01/2006 22:30:00   Logboeknr  RBV  :   96 Tijd: 2230   VL-Post: ...
#
#      stm_mon_begin_ddt                         stm_sap_meldtekst  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                          object
# #stm_sap_meldnr                      int64
# stm_mon_nr                         float64
# stm_vl_post                         object
# stm_sap_meld_ddt                    object
# stm_sap_mon_meld_ddt                object
# stm_sap_meldtekst_lang              object
# stm_mon_begin_ddt                   object
# stm_sap_meldtekst                   object
# stm_mon_toelichting_trdl            object
# stm_oh_pg_mld                       object
# stm_geo_mld                         object
# stm_geo_mld_uit_functiepl          float64
# stm_equipm_nr_mld                  float64
# stm_equipm_soort_mld                object
# stm_equipm_omschr_mld               object
# stm_km_van_mld                     float64
# stm_km_tot_mld                     float64
# stm_prioriteit                     float64
# stm_scenario_mon                    object
# stm_status_melding_sap              object
# stm_mon_nr_status_omschr            object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '#stm_sap_meldnr', 'stm_mon_nr', 'stm_vl_post',
#        'stm_sap_meld_ddt', 'stm_sap_mon_meld_ddt', 'stm_sap_meldtekst_lang',
#        'stm_mon_begin_ddt', 'stm_sap_meldtekst', 'stm_mon_toelichting_trdl',
#        ...
#        'stm_rapportage_maand', 'stm_rapportage_jaar', 'stm_x_bron_publ_dt',
#        'stm_x_bron_bestandsnaam', 'stm_x_bron_arch_dt', 'stm_x_actueel_ind',
#        'stm_x_run_id', 'stm_x_bk', 'stm_x_start_sessie_dt',
#        'stm_x_vervallen_ind'],
#       dtype='object', length=140)

# %%
df.describe().T
# Out:
#                               count          mean           std         min  \
# #stm_sap_meldnr            898526.0  7.510690e+07  1.113009e+07         0.0
# stm_mon_nr                 898525.0  9.163174e+05  1.588361e+06         0.0
# stm_geo_mld_uit_functiepl  884926.0  3.350056e+02  2.749061e+02         0.0
# stm_equipm_nr_mld          661126.0  1.064512e+07  4.748398e+05  10000012.0
# stm_km_van_mld             898522.0  3.536605e+04  2.294758e+05         0.0
# stm_km_tot_mld             898522.0  1.594005e+04  4.969935e+04         0.0
# stm_prioriteit             898365.0  4.582593e+00  2.262522e+00         1.0
# stm_mon_nr__statuscode     326841.0  4.489137e+00  2.911721e+00         0.0
# stm_geo_gst_uit_functiepl  741568.0  3.214555e+02  2.706875e+02         0.0
# stm_equipm_nr_gst          605721.0  1.062666e+07  4.755891e+05  10000012.0
# stm_km_van_gst             898521.0  2.664714e+04  7.841763e+04         0.0
# ...

# %%
geo = pd.read_csv('geocodes.csv',error_bad_lines=False)
# Out:
# b'Skipping line 309: expected 1 fields, saw 2\n'

# %%
geo
# Out:
#                                           Code;Traject
# 0                       1;Harlingen Haven - Leeuwarden
# 1                             2;Leeuwarden - Groningen
# 2           3;Groningen Losplaats - Waterhuizen Aansl.
# 3                     4;Waterhuizen Aansl. - Zuidbroek
# 4                     5;Zuidbroek - Nieuweschans Grens
# 5                                6;Groningen - Sauwerd
# 6                                   7;Sauwerd - Winsum
# 7                              8;Leeuwarden - Stavoren
# 8                                9;Meppel - Leeuwarden
# 9                       10;Haren - Groningen Losplaats
# 10                                    11;Assen - Haren
# 11                                   12;Meppel - Assen
# 12                           13;Herfte Aansl. - Meppel
# 13                           14;Zwolle - Herfte Aansl.
# 14                                  15;Zwolle - Kampen
# 15                17;Amersfoort Aansl. - Hattemerbroek
# ...

# %%
oorzaak = pd.read_csv('Oorzaakcodes.csv',error_bad_lines=False)
# Out:
# b'Skipping line 8: expected 1 fields, saw 2\nSkipping line 68: expected 1 fields, saw 3\n'

# %%
oorzaak
# Out:
#                                        Code;Oorzaak
# 0                    131;Uitloop treinvrije periode
# 1                                132;Ongepland werk
# 2                                 133;Werkzaamheden
# 3      134;Aanrijding (bijna) tijdens werkzaamheden
# 4               141;Bijna aanrijding met wegverkeer
# 5       142;Bijna aanrijding met persoon langs baan
# 6                        144;Openrijden/kapotrijden
# 7                     152;Aanrijding met wegverkeer
# 8         153;Aanrijding met personen langs de baan
# 9                               146;Vreemd voorwerp
# 10                       250;Belemmerende vegetatie
# 11                                     154;Diefstal
# 12                                   145;Vandalisme
# 13       147;Ondeskundig gebruik derden (bediening)
# 14                                151;Overig derden
# 15          140;Schade door weg-/werk-/waterverkeer
# 16                          150;Vervuiling (derden)
# ...

# %%
df['stm_geo_mld'][:5]
# Out:
# 0    NaN
# 1    624
# 2    201
# 3     25
# 4     12
# Name: stm_geo_mld, dtype: object

# %%
df['stm_oh_pg_gst'][:5] #Contract gebied storing + aanduiding techniekveld
# Out:
# 0    NaN
# 1    81S
# 2    37B
# 3    32B
# 4    35B
# Name: stm_oh_pg_gst, dtype: object

# %%
cg = pd.read_csv('Contractgebiedcodes.csv',error_bad_lines=False) #Contract gebied storing
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-65a7e5abf9e3> in <module>
# ----> 1 cg = pd.read_csv('Contractgebiedcodes.csv',error_bad_lines=False) #Contract gebied storing
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...
