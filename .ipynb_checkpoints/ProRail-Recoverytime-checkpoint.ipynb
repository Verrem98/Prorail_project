# %% [markdown]
# # Data-driven business -- ProRail Hersteltijd
#
# **********************************************************************************************************
# **********************************************************************************************************
#
# ![1200px-ProRaillogo](1200px-ProRail_logo.png)
# ![hu-logo-en](hu-logo-en.png)
#
# ***********************************************************************************************************
# ***********************************************************************************************************
#
# ## <span style='font-family:font_family name'> Groep : V2A-PG3 </span>
# ## <span style='font-family:font_family name'> Emiel Verhoef , Studentnummer : </span>
# ## <span style='font-family:font_family name'> Stan Haakman , Studentnummer : </span>
# ## <span style='font-family:font_family name'> Khai-Tam Nguyen , Studentnummer : </span>
# ## <span style='font-family:font_family name'> Hussin Almoustafa , Studentnummer : 1776495 </span>

# %% [markdown]
# ## Doel
# De doelstelling van het project is om de planners te helpen om de hervatting van het treinverkeer te organiseren. In de praktijk blijkt dat de voorspellingen van de monteurs vaak te pessimistisch zijn. De vraag van ProRail en de planners van de NS is of op basis van de data een betere voorspelling te maken is waardoor de dienstregeling sneller hervat kan worden.
# ![1](1.png)
#
#
# ## Data understanding
# De fase van  Data understanding van CRISP-DM omvat het nader bekijken van de data die beschikbaar zijn voor mijnbouw. Deze stap is van cruciaal belang om onverwachte problemen te voorkomen tijdens de volgende fase - Data preparation - die doorgaans het langste deel van een project is.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import scipy.stats as stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-75-ef76170a3280> in <module>
#       3 import matplotlib.pyplot as plt
#       4 import scipy.stats as stats
# ----> 5 from ggplot import *
#
# ModuleNotFoundError: No module named 'ggplot'

# %%
#ProRail cvs Data file 
df = pd.read_csv('sap_storing_data_hu_project.csv')
df['#stm_sap_meldnr'].sort_index(inplace = True)
df.drop_duplicates(subset = '#stm_sap_meldnr', keep = 'last',inplace = True) #Alle duplicates waarden droppen
# Out:
# C:\Users\hasso\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (0,11,19,21,24,25,27,32,33,36,37,38,39,40,46,47,48,49,51,53,55,56,60,73,75,78,80,82,83,86,87,91,95,99,102,103,104,107,108,109,110,111,112,113,116,118,119,120,121,122,123,124,129) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_rows', df.shape[0]+1) #max aantal rows

# %%
df.shape #Data Frame Shape
# Out:
# (566481, 140)

# %%
set(list(df.columns)) #Alle kolomen
# Out:
# {'#stm_sap_meldnr',
#  'Unnamed: 0',
#  'stm_aangelegd_dd',
#  'stm_aangelegd_tijd',
#  'stm_aanngeb_dd',
#  'stm_aanngeb_ddt',
#  'stm_aanngeb_tijd',
#  'stm_aanntpl_dd',
#  'stm_aanntpl_ddt',
#  'stm_aanntpl_tijd',
#  'stm_actie',
#  'stm_afsluit_dd',
#  'stm_afsluit_ddt',
#  'stm_afsluit_tijd',
#  'stm_afspr_aanvangdd',
#  'stm_afspr_aanvangddt',
#  'stm_afspr_aanvangtijd',
#  'stm_afspr_func_hersteldd',
#  'stm_afspr_func_hersteltijd',
#  'stm_akkoord_melding_jn',
#  'stm_akkoord_mon_toewijz',
#  'stm_arbeid',
#  'stm_contractgeb_gst',
#  'stm_contractgeb_mld',
#  'stm_controle_dd',
#  'stm_dir_betrok_tr',
#  'stm_dstrglp_naar',
#  'stm_dstrglp_van',
#  'stm_effect',
#  'stm_equipm_nr_gst',
#  'stm_equipm_nr_mld',
#  'stm_equipm_omschr_gst',
#  'stm_equipm_omschr_mld',
#  'stm_equipm_soort_gst',
#  'stm_equipm_soort_mld',
#  'stm_evb',
#  'stm_fact_jn',
#  'stm_fh_dd',
#  'stm_fh_ddt',
#  'stm_fh_duur',
#  'stm_fh_status',
#  'stm_fh_tijd',
#  'stm_functiepl_gst',
#  'stm_functiepl_mld',
#  'stm_geo_gst',
#  'stm_geo_gst_uit_functiepl',
#  'stm_geo_mld',
#  'stm_geo_mld_uit_functiepl',
#  'stm_hinderwaarde',
#  'stm_historie_toelichting',
#  'stm_km_tot_gst',
#  'stm_km_tot_mld',
#  'stm_km_van_gst',
#  'stm_km_van_mld',
#  'stm_mon_begin_ddt',
#  'stm_mon_begindatum',
#  'stm_mon_begintijd',
#  'stm_mon_eind_datum',
#  'stm_mon_eind_ddt',
#  'stm_mon_eind_tijd',
#  'stm_mon_nr',
#  'stm_mon_nr__statuscode',
#  'stm_mon_nr_status_omschr',
#  'stm_mon_nr_status_wijzdd',
#  'stm_mon_toelichting_trdl',
#  'stm_mon_vhdsincident',
#  'stm_objectdl_code_gst',
#  'stm_objectdl_groep_gst',
#  'stm_oh_pg_gst',
#  'stm_oh_pg_mld',
#  'stm_oorz_code',
#  'stm_oorz_groep',
#  'stm_oorz_tekst_kort',
#  'stm_oorz_tkst',
#  'stm_pplg_naar',
#  'stm_pplg_van',
#  'stm_prioriteit',
#  'stm_progfh_gw_datum',
#  'stm_progfh_gw_ddt',
#  'stm_progfh_gw_duur',
#  'stm_progfh_gw_lwd_datum',
#  'stm_progfh_gw_lwd_ddt',
#  'stm_progfh_gw_lwd_tijd',
#  'stm_progfh_gw_teller',
#  'stm_progfh_gw_tijd',
#  'stm_progfh_hz',
#  'stm_progfh_in_datum',
#  'stm_progfh_in_ddt',
#  'stm_progfh_in_duur',
#  'stm_progfh_in_invoer_dat',
#  'stm_progfh_in_invoer_ddt',
#  'stm_progfh_in_invoer_tijd',
#  'stm_progfh_in_tijd',
#  'stm_projnr',
#  'stm_rapportage_jaar',
#  'stm_rapportage_maand',
#  'stm_reactie_duur',
#  'stm_rec_toegev_ddt',
#  'stm_relatiervo',
#  'stm_relatiervo_volgend',
#  'stm_relatiervo_vorig',
#  'stm_sap_meld_ddt',
#  'stm_sap_melddatum',
#  'stm_sap_meldtekst',
#  'stm_sap_meldtekst_lang',
#  'stm_sap_meldtijd',
#  'stm_sap_mon_meld_ddt',
#  'stm_sap_storeind_ddt',
#  'stm_sap_storeinddatum',
#  'stm_sap_storeindtijd',
#  'stm_scenario_mon',
#  'stm_schade_status_ga',
#  'stm_schade_statusdatum',
#  'stm_schade_verhaalb_jn',
#  'stm_schadenr',
#  'stm_sorteerveld',
#  'stm_standplaats',
#  'stm_status_gebr',
#  'stm_status_melding_sap',
#  'stm_status_sapnaarmon',
#  'stm_tao_beinvloedbaar_indicator',
#  'stm_tao_indicator',
#  'stm_tao_indicator_vorige',
#  'stm_tao_soort_mutatie',
#  'stm_tao_telling_mutatie',
#  'stm_techn_gst',
#  'stm_techn_mld',
#  'stm_veroorz_code',
#  'stm_veroorz_groep',
#  'stm_veroorz_tekst_kort',
#  'stm_vl_post',
#  'stm_wbi_nummer',
#  'stm_x_actueel_ind',
#  'stm_x_bk',
#  'stm_x_bron_arch_dt',
#  'stm_x_bron_bestandsnaam',
#  'stm_x_bron_publ_dt',
#  'stm_x_run_id',
#  'stm_x_start_sessie_dt',
#  'stm_x_vervallen_ind'}

# %%
#Het datatype van de datasetattributen weergeven
df.dtypes
# Out:
# Unnamed: 0                object
# #stm_sap_meldnr            int64
# stm_mon_nr               float64
# stm_vl_post               object
# stm_sap_meld_ddt          object
#                           ...
# stm_x_actueel_ind          int64
# stm_x_run_id               int64
# stm_x_bk                   int64
# stm_x_start_sessie_dt     object
# stm_x_vervallen_ind        int64
# Length: 140, dtype: object

# %%
df.head()
# Out:
#   Unnamed: 0  #stm_sap_meldnr  stm_mon_nr stm_vl_post     stm_sap_meld_ddt  \
# 0          0                0         NaN         NaN                  NaN
# 1          1         50053211         0.0         NaN  02/01/2006 09:00:00
# 2          2         50053213        48.0          GN  02/01/2006 12:35:00
# 3          3         50053214        72.0          ZL  02/01/2006 16:40:00
# 4          4         50053215        96.0          ZL  02/01/2006 22:30:00
#
#   stm_sap_mon_meld_ddt                             stm_sap_meldtekst_lang  \
# 0                  NaN                                                NaN
# 1  02/01/2006 09:00:00   Logboeknr  Geeltje  :   49 Tijd: 0900   VL-Po...
# 2  02/01/2006 12:35:00   Logboeknr  RBV  :   48 Tijd: 1235   VL-Post: ...
# 3  02/01/2006 16:40:00   Logboeknr  RBV  :   72 Tijd: 1640   VL-Post: ...
# 4  02/01/2006 22:30:00   Logboeknr  RBV  :   96 Tijd: 2230   VL-Post: ...
#
#      stm_mon_begin_ddt                         stm_sap_meldtekst  \
# 0                  NaN                                       NaN
# 1                  NaN     Logboeknr  Geeltje  :   49 Tijd: 0900
# 2  02/01/2006 12:35:00  Logboeknr  RBV  :   48 Tijd: 1235   VL-P
# 3  02/01/2006 16:40:00  Logboeknr  RBV  :   72 Tijd: 1640   VL-P
# 4  02/01/2006 22:30:00  Logboeknr  RBV  :   96 Tijd: 2230   VL-P
#
#   stm_mon_toelichting_trdl  ... stm_rapportage_maand stm_rapportage_jaar  \
# 0                      NaN  ...                    5                2014
# 1                      NaN  ...                    1                2006
# 2                      NaN  ...                    1                2006
# 3                      NaN  ...                    1                2006
# 4                      NaN  ...                    1                2006
#
#     stm_x_bron_publ_dt                            stm_x_bron_bestandsnaam  \
# 0  07/05/2014 05:30:12  \\PUHAPS0149\Informatica_Prod\Inbox\Informatic...
# 1  02/01/2006 09:00:00  \\PUHAPS0149\Informatica_Prod\Inbox\Informatic...
# 2  02/01/2006 12:35:00  \\PUHAPS0149\Informatica_Prod\Inbox\Informatic...
# 3  02/01/2006 16:40:00  \\PUHAPS0149\Informatica_Prod\Inbox\Informatic...
# 4  02/01/2006 22:30:00  \\PUHAPS0149\Informatica_Prod\Inbox\Informatic...
#
#     stm_x_bron_arch_dt stm_x_actueel_ind  stm_x_run_id  stm_x_bk  \
# 0  31/12/9999 00:00:00                 1         34415   3617016
# 1  31/12/9999 00:00:00                 1          1518  12704590
# 2  31/12/9999 00:00:00                 1          1518  12704591
# 3  31/12/9999 00:00:00                 1          1518  12704592
# 4  31/12/9999 00:00:00                 1          1518  12704593
#
#    stm_x_start_sessie_dt stm_x_vervallen_ind
# 0    07/05/2014 05:44:24                   0
# 1    13/06/2013 13:37:52                   0
# 2    13/06/2013 13:37:52                   0
# 3    13/06/2013 13:37:52                   0
# 4    13/06/2013 13:37:52                   0
#
# [5 rows x 140 columns]

# %% [markdown]
# ## Data preparation
# Data preparation is het opschonen, structureren en verrijken van ruwe data tot een gewenste output voor analyse. Het wordt gewoonlijk 'conciërgewerk' genoemd, maar het is enorm belangrijk en cruciaal voor de missie om robuuste, nauwkeurige downstream-analyses te garanderen. Als datavoorbereiding op de juiste manier wordt uitgevoerd, krijgt u inzicht in de aard van uw gegevens, zodat u er betere vragen over kunt stellen.

# %%
#functie om outliers verwijderen 
def column_outlier(strength, dataframe, columns):
    temp_dataframe = dataframe.copy()
    try:
        if strength == 's':
            strength=3
        elif strength == 'a':
            strength=1.5
    except:
        print("Invalid strength")
    for column in columns:
        Q1 = temp_dataframe[column].quantile(0.25)
        Q3 = temp_dataframe[column].quantile(0.75)
        IQR = Q3 - Q1
        temp_dataframe = temp_dataframe[~((temp_dataframe[column] < (Q1 - strength * IQR)) |(temp_dataframe[column] > (Q3 + strength* IQR)))]
    return temp_dataframe

# %%
#functie om dummies te creeren voor een kolom
def create_dummies(target_df, source_df, column):
    return target_df.join(pd.get_dummies(source_df.iloc[target_df.index][column]))

# %% [markdown]
# We gaan Natuurlijk de herstel tijd voorspelen. dus laten we de kolom [stm_fh_duur] opschonen en daarna plotten.

# %%
# we willen alleen durations die niet gelijk zijn aan 0 en kleiner zijn dan 8 uur
df = df[(df.stm_fh_duur != 0) & (df.stm_fh_duur <= 480)]

# %%
import seaborn as sns

# %%
sns.kdeplot(df.stm_fh_duur)
# Out:
# <AxesSubplot:xlabel='stm_fh_duur', ylabel='Density'>

# %% [markdown]
# We hebben zeker veel data en niet alle data gaan we meenemen naar onze Modellen dus laten de features bepalen aan de hand van een Corrlatie maar eerst de outliers droppen.
#
# De donkere kleur toont de hoge correlatie tussen de variabelen en de lichte kleuren toont minder correlatie tussen de variabelen.

# %%
corr = df.corr() #Corr matriex
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col0,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row1_col1,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row2_col2,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row3_col3,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row4_col4,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row5_col5,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row6_col6,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row7_col7,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row8_col8,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row9_col9,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row10_col10,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row11_col11,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row12_col12,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row13_col13,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row14_col14,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row15_col15,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row16_col16,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row17_col17,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row18_col18,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row19_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row20_col20,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row21_col21,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row22_col22,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row23_col23,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row24_col24,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row25_col25,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row26_col26,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row27_col27,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row28_col28,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row29_col29{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col1,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col17,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row3_col10,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row5_col24,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row10_col23,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row11_col24,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row17_col10,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row22_col23,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row22_col24,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row25_col23,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row26_col22{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col2,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col12,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row1_col15,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row1_col20,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row5_col29,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row6_col2,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row10_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row10_col22,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row12_col1,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row12_col5,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row13_col5,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row13_col11,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row17_col5,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row21_col29,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row22_col6,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row24_col6,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row26_col6{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col3,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row2_col5,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row3_col22,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row10_col15,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row12_col6,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row19_col22,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row22_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row28_col15,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row29_col5,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row29_col11{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col4,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row1_col6,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row14_col10,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row15_col10,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row15_col19{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col5,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col24,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row1_col13,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row4_col13,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row5_col26,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row7_col8,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row9_col12,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row11_col26,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row17_col20,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row17_col26,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row21_col26,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row23_col13,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row24_col8{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col6,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row1_col26,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row3_col24,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row6_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row12_col24,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row25_col10{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col7,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row2_col28,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row4_col25,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row24_col25{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col8,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row4_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row6_col8,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row6_col22,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row9_col17,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row11_col2,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row11_col4,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row14_col29,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row16_col2,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row16_col22,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row18_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row21_col8,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row23_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row24_col14,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row29_col20{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col9,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col20,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row1_col29,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row4_col14,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row9_col8,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row12_col29,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row13_col21,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row13_col22,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row14_col11,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row14_col15,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row14_col17,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row18_col14,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row20_col14,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row20_col29,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row23_col6,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row23_col17,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row23_col20,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row26_col17,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row26_col20{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col10,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row3_col4,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row3_col23,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row7_col4,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row9_col4,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row16_col4,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row16_col19,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row21_col13{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row0_col11,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row2_col1,#T_b308421b_3ca4_11ec_8ab4_a86daa0e2451row2_col19,#T_b308421b_3ca4

# %%
df.corr()['stm_fh_duur'] #Corrlatie on onze target
# Out:
# #stm_sap_meldnr              0.005773
# stm_mon_nr                   0.017230
# stm_geo_mld_uit_functiepl   -0.030343
# stm_equipm_nr_mld           -0.049695
# stm_km_van_mld               0.007528
# stm_km_tot_mld               0.028076
# stm_prioriteit               0.142124
# stm_mon_nr__statuscode       0.011634
# stm_geo_gst_uit_functiepl   -0.020571
# stm_equipm_nr_gst           -0.013051
# stm_km_van_gst               0.021245
# stm_km_tot_gst               0.026963
# stm_oorz_code               -0.103402
# stm_fh_status               -0.119846
# stm_tao_telling_mutatie     -0.017077
# stm_contractgeb_mld         -0.182659
# stm_contractgeb_gst         -0.160130
# stm_arbeid                  -0.056707
# stm_progfh_gw_lwd_datum      0.075430
# stm_progfh_gw_teller         0.112955
# stm_fh_duur                  1.000000
# stm_reactie_duur            -0.021064
# stm_status_sapnaarmon        0.011485
# stm_schadenr                 0.006441
# stm_rapportage_maand         0.002086
# stm_rapportage_jaar          0.027630
# stm_x_actueel_ind            0.002986
# stm_x_run_id                 0.022604
# stm_x_bk                    -0.018303
# stm_x_vervallen_ind         -0.007012
# Name: stm_fh_duur, dtype: float64

# %%
# ik zorg er hier voor dat de 'stm_progfh_in_duur' kolom naar floats gecast wordt
df.stm_progfh_in_duur = df.stm_progfh_in_duur.apply(lambda x: float(str(x).replace('-','').replace('*','').strip()))
df.stm_progfh_in_duur.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# De kolom [stm_sap_melddatum] bevat de datum van de melding , Hier gaan we de datum naar sezoenen en week nummer converteren.

# %%
# voeg dummy kolommen voor seizoenen toe
df.stm_sap_melddatum = pd.to_datetime(df.stm_sap_melddatum)

df['date_offset'] = (df.stm_sap_melddatum.dt.month*100 + df.stm_sap_melddatum.dt.day - 320)%1300

df['seizoen_melding'] = pd.cut(df.copy()['date_offset'], [0, 300, 602, 900, 1300], 
                      labels=['spring', 'summer', 'autumn', 'winter'])

df.drop(['date_offset'], axis=1)
df = df.join(pd.get_dummies(df.seizoen_melding))
df['seizoen_melding'].value_counts()
# Out:
# summer    93837
# spring    92732
# winter    89686
# autumn    88033
# Name: seizoen_melding, dtype: int64

# %%
# maak een kolom voor weeknummers van de melding
df['weeknr']= df.stm_sap_melddatum.dt.isocalendar().week.apply(lambda x: 'w' + str(x))

# %% [markdown]
# Nu kunnen we de vertaling van kolommen [stm_techn_mld],[stm_contractgeb_gst],[stm_geo_mld],[stm_oorz_code] toevoegen door een externe data's set's

# %%
# join de oorzaakcodes
o_df = pd.read_csv('Oorzaakcodes.csv', sep = ';')
o_df = o_df.rename(columns={'Code': 'stm_oorz_code'})
df = df.merge(o_df, on = 'stm_oorz_code', how = 'outer')

# %%
# outlier verwijderen en de mean van fh_duur berekenen voor eelke oorzaak 
mean_oorzaak_df = column_outlier('a', df.copy(), ['stm_fh_duur'])[['stm_fh_duur', 'Oorzaak']].groupby('Oorzaak', as_index = False).mean()
mean_oorzaak_df
# Out:
#                                         Oorzaak  stm_fh_duur
# 0      Aanrijding (bijna) tijdens werkzaamheden    83.625954
# 1         Aanrijding met personen langs de baan          NaN
# 2                     Aanrijding met wegverkeer          NaN
# 3                   Afstelling onjuist/verlopen   119.921819
# 4                       Applicatie/softwarefout    48.132208
# 5                        Belemmerende vegetatie   124.150862
# 6   Bij onderzoek in orde/geen oorzaak gevonden    94.706647
# 7       Bijna aanrijding met persoon langs baan    45.555757
# 8               Bijna aanrijding met wegverkeer    72.355301
# 9                                  Braamvorming   100.297101
# 10    Brand(alarm), bommelding, gevaar/explosie    71.211300
# 11             Breuk/scheurvorming/afbrokkeling   115.598720
# 12                          Corrosie/aantasting   118.566922
# 13  Defect bijzonder voertuig tijdens transport    93.326087
# 14                                     Diefstal   117.556485
# 15    Dieren, schade door of (bijna) aanrijding   118.787171
# 16                                  Doorbranden   101.947880
# 17                                  EMC/bliksem   121.813458
# 18                     Extreem hoge temperatuur    88.333570
# 19                     Extreem lage temperatuur   119.287958
# 20                                Fabricagefout   133.294215
# 21                               Geen onderzoek    50.272349
# 22          Gladde sporen (bladval/chemicalien)    88.908571
# 23                                 Golfslijtage   107.812500
# 24                                 Groefvorming   101.090909
# 25                           IJsafzetting/ijzel   114.869338
# 26                   In- en uitzetten materieel    74.960000
# 27                           Ingebrand/verbrand   115.557550
# 28                                     Inrijden   106.545455
# 29                                     Isolatie   116.113208
# 30                                     Katterug   113.523810
# 31                                      Klapper   110.079422
# 32                                  Kortsluiten   111.052332
# 33                                      Lekkage   115.500000
# 34     Levering nutsbedrijf: elek/gas/water/tel    93.842213
# 35                                  Montagefout   124.564280
# 36                                  Niet gemeld    53.257204
# 37                    Omhoog werken/verschuiven   114.373134
# 38      Onderdeel defect door onbekende oorzaak   117.545131
# 39       Ondeskundig gebruik derden (bediening)    96.040207
# 40                               Ongepland werk   106.480769
# 41     Onjuiste geometrie/ligging/blinde vering   115.946164
# 42                        Onvoldoende onderhoud   114.494475
# 43                          Onvoldoende smering   109.028668
# 44                       Openrijden/kapotrijden   121.294118
# 45                                Overbelasting   118.573109
# 46                                Overig derden    90.610501
# 47                             Overig processen    98.061068
# 48                             Overig technisch    95.108498
# 49                                 Overspanning   132.515504
# 50                                   Pekel/zout   112.138824
# 51                              RCF (headcheck)   115.176015
# 52                    Regen/vocht/wateroverlast   123.372514
# 53          Schade door weg-/werk-/waterverkeer   107.123116
# 54                                     Slijtage   118.234854
# 55                                 Sneeuw/hagel   102.364784
# 56                                        Storm   115.165188
# 57                                  Systeemfout   112.830983
# 58                                   Trillingen   110.122532
# 59                   Uitloop treinvrije periode    77.437888
# 60                                   Uitwalsing   105.697605
# 61                                   Vandalisme    90.175709
# 62                                  Vastgelopen   134.620773
# 63                            Verbogen/vervormd   106.149123
# 64                                  Veroudering   129.777050
# 65                                       Verrot   106.021978
# 66                          Vervuiling (derden)   104.351690
# 67                       Vervuiling (technisch)   100.438450
# 68                     Verzakking/klink/zetting   119.882521
# 69                              Vreemd voorwerp    92.805417
# 70                                Werkzaamheden   105.712668

# %%
x = 'Oorzaak'
y = 'stm_fh_duur'
plt.figure(figsize=(20,20))
new_data= mean_oorzaak_df.sort_values(by ='stm_fh_duur' , ascending=False)
new_data_sort=mean_oorzaak_df
ax=sns.pointplot(new_data_sort['stm_fh_duur'], new_data_sort['Oorzaak'], hue=new_data_sort['Oorzaak'])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hasso\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# join de goetrajectcodes
geo_df = pd.read_csv('geocodes.csv',sep = ';') 
geo_df = geo_df.rename(columns={'Code': 'stm_geo_mld'}) 
df = df.merge(geo_df, on = 'stm_geo_mld', how = 'outer')

# %%
# outlier verwijderen en de mean van fh_duur berekenen voor eelke Traject  
mean_traject_df = column_outlier('a', df.copy(), ['stm_fh_duur'])[['stm_fh_duur', 'Traject']].groupby('Traject', as_index = False).mean()
mean_traject_df
# Out:
#                                                Traject  stm_fh_duur
# 0                        Aachen (D) - Herzogenrath (D)          NaN
# 1                                              Alkmaar    50.065217
# 2                                   Alkmaar - Uitgeest   102.285714
# 3                                               Almelo    74.444444
# 4                                     Almelo - Hengelo    29.000000
# 5                                     Almelo Dollegoor          NaN
# 6                                 Almelo Gem. Stamlijn          NaN
# 7                                      Alphen a/d Rijn    66.000000
# 8                    Alphen a/d Rijn - Leiden Centraal   110.714286
# 9           Alphen a/d Rijn Industrieterrein Rijnhaven          NaN
# 10                                          Amersfoort    64.857143
# 11                                   Amersfoort Aansl.    77.250000
# 12                 Amersfoort Aansl. - Barneveld Noord   123.333333
# 13                   Amersfoort Aansl. - Hattemerbroek   120.538462
# 14                              Amersfoort Bokkeduinen    52.000000
# 15                          Amersfoort Hoofdwerkplaats    58.000000
# 16               Amstelveen - Amsterdam Haarlemmermeer          NaN
# 17                               Amstelveen - Uithoorn          NaN
# 18                              Amsterdam - Vlissingen          NaN
# 19             Amsterdam Bijlmer - Nieuwersluis-Loenen    78.500000
# 20                             Amsterdam Bijlmer Arena   115.000000
# 21                                  Amsterdam Centraal    64.322034
# 22                               Amsterdam Dijksgracht   149.500000
# 23                         Amsterdam Hemhaven (gebied)    33.000000
# 24                    Amsterdam Houtrakpolder (gebied)    84.055556
# 25                            Amsterdam Lijnwerkplaats   123.800000
# 26                               Amsterdam Muiderpoort    30.500000
# 27                      Amsterdam Muiderpoort - Diemen   132.000000
# 28                Amsterdam Muiderpoort - Duivendrecht    75.000000
# 29                              Amsterdam Riekerpolder    99.250000
# 30                    Amsterdam Riekerpolder - Warmond   121.790698
# 31                       Amsterdam Singelgracht Aansl.   102.833333
# 32                                Amsterdam Sloterdijk   102.600000
# 33       Amsterdam Sloterdijk - Amsterdam Riekerpolder    40.111111
# 34                      Amsterdam Sloterdijk - Haarlem   157.000000
# 35                        Amsterdam Westhaven (gebied)   111.750000
# 36                     Amsterdam Westhaven - Oldenzaal          NaN
# 37                                           Apeldoorn   136.125000
# 38                                Apeldoorn - Deventer    67.000000
# 39                                 Apeldoorn - Zutphen   133.833333
# 40                                              Arnhem    70.357895
# 41                                       Arnhem - Elst   148.000000
# 42                         Arnhem - Velperbroek Aansl.          NaN
# 43                                Arnhem Gem. Stamlijn          NaN
# 44         Arnhem Goederenstation - Velperbroek Aansl.    93.500000
# 45                                               Assen    25.000000
# 46                                  Axel Axelse Vlakte   150.000000
# 47                                               Baarn    90.625000
# 48                                  Baarn - Amersfoort   113.000000
# 49                                     Barneveld Noord    60.000000
# 50                         Barneveld Noord - Apeldoorn   110.666667
# 51                    Barneveld Noord - Ede-Wageningen    78.181818
# 52                                              Beugen          NaN
# 53                                    Beugen - Blerick    36.000000
# 54               Beverwijk Hoogovens - Roosendaal/Sloe          NaN
# 55                      Beverwijk Hoogovens - Zevenaar          NaN
# 56                     Beverwijk Hoogovens, Van Gelder   111.000000
# 57                                          Blauwkapel    77.166667
# 58                             Blauwkapel - Den Dolder    60.000000
# 59                                             Blerick   115.428571
# 60                                 Blerick - Eindhoven    79.882353
# 61                                Born Franciscushaven          NaN
# 62                                              Botlek   161.000000
# 63                                        Botlektunnel   159.750000
# 64                                              Boxtel    55.833333
# 65                                  Boxtel - Eindhoven   127.000000
# 66                                       Boxtel - Uden          NaN
# 67                                               Breda    75.090909
# 68                                Breda - Lage Zwaluwe    82.500000
# 69                                     Breda - Tilburg   118.680000
# 70                                           Breukelen    83.000000
# 71                         Breukelen - Harmelen Aansl.   110.250000
# 72                        Breukelen - Utrecht Centraal    97.500000
# 73                                 Budel Grens - Weert          NaN
# 74                                   Budel Zinkfabriek          NaN
# 75                                         CUP Valburg   213.000000
# 76                         Coevorden - Coevorden Grens          NaN
# 272                               Rotterdam Maasvlakte          NaN
# 273                       Rotterdam Rijn- en Maashaven          NaN
# 274                           Rotterdam Waalhaven Oost   117.833333
# 275                     Rotterdam Westelijke Splitsing    96.916667
# 276      Rotterdam Westelijke Splitsing - Nieuw Vennep   121.777778
# 277     Rotterdam Zuid Goederen - Rotterdam Maasvlakte   130.792000
# 278                                    Santpoort Noord   108.250000
# 279                         Santpoort Noord - IJmuiden          NaN
# 280                         Santpoort Noord - Uitgeest    89.454545
# 281                              Sas van Gent Cerestar          NaN
# 282              Sas van Gent Grens - Terneuzen Aansl.   117.500000
# 283                                            Sauwerd    57.500000
# 284                                 Sauwerd - Delfzijl   138.333333
# 285                                   Sauwerd - Winsum    19.500000
# 286                                   Schiedam Centrum    85.000000
# 287         Schiedam Centrum - Hoek van Holland Strand   104.108108
# 288                                      Schin op Geul          NaN
# 289                         Schin op Geul - Maastricht   139.000000
# 290                                         Simpelveld          NaN
# 291                         Simpelveld - Schin op Geul          NaN
# 292                      Simpelveld Grens - Simpelveld          NaN
# 293                                            Sittard   177.333333
# 294                                     Sittard - Born   128.000000
# 295                                  Sittard - Heerlen   130.000000
# 296                                 Sittard - Roermond   115.000000
# 297                                       Sloe - Venlo          NaN
# 298  Stadskanaal Hoofdstation - Musselkanaal-Valthe...          NaN
# 299               Stadskanaal Hoofdstation - Zuidbroek    96.000000
# 300                                   Terneuzen Aansl.          NaN
# 301                       Terneuzen Aansl. - Terneuzen          NaN
# 302                             Terneuzen Dow Chemical    35.000000
# 303                                 Tiel Gem. Stamlijn          NaN
# 304                                            Tilburg   103.866667
# 305                                   Tilburg - Boxtel   123.846154
# 306                             Tilburg - Vught Aansl.   117.555556
# 307                            Tilburg Hoofdwerkplaats          NaN
# 308                                   Tilburg de Loven          NaN
# 309                                           Uitgeest   119.400000
# 310                                 Uitgeest - Zaandam   117.916667
# 311                        Uitgeest/Haarlem - Zevenaar          NaN
# 312                       Utrecht - Heerlen/Maastricht          NaN
# 313                                   Utrecht Centraal    74.017442
# 314                      Utrecht Centraal - Blauwkapel    68.000000
# 315                 Utrecht Centraal - Harmelen Aansl.    83.000000
# 316                Utrecht Industrieterrein Lage Weide          NaN
# 317                                VAM-terrein Wijster          NaN
# 318                                 Velperbroek Aansl.   217.500000
# 319                        Velperbroek Aansl. - Dieren    53.333333
# 320                      Velperbroek Aansl. - Zevenaar    26.000000
# 321                                              Venlo    87.814815
# 322                               Venlo -Lutterade DSM          NaN
# 323                           Venlo Grens - Keulen (D)          NaN
# 324                                Venlo Grens - Venlo          NaN
# 325                                    Venlo Tradeport          NaN
# 326                    Vetschau (D) - Simpelveld Grens          NaN
# 327                           Visé (B) - Eijsden Grens          NaN
# 328                               Vlissingen Sloehaven    75.500000
# 329                                               Vork          NaN
# 330                                    Vork - Kesteren          NaN
# 331                                       Vught Aansl.   101.500000
# 332                              Vught Aansl. - Boxtel          NaN
# 333                                            Warmond   162.000000
# 334                          Warmond - Leiden Centraal          NaN
# 335                                    Watergraafsmeer   116.272727
# 336                                 Waterhuizen Aansl.    93.000000
# 337                     Waterhuizen Aansl. - Zuidbroek    47.750000
# 338                                              Weert    94.600000
# 339                                   Weert - Roermond   132.600000
# 340                                       Weesp Aansl.    98.200000
# 341                           Weesp Aansl. - Hilversum   129.428571
# 342           Weesp Aansl. - Lelystad Industrieterrein   117.666667
# 343                                            Wierden   130.750000
# 344                                   Wierden - Almelo    44.000000
# 345                               Winsum - Roodeschool   102.066667
# 346                                        Winterswijk    61.555556
# 347                             Winterswijk - Zevenaar   105.107143
# 348                                            Woerden   121.875000
# 349                          Woerden - Alphen a/d Rijn    60.142857
# 350                                    Woerden - Gouda   114.400000
# 351               Woudenberg-Scherpenzeel - Amersfoort          NaN
# 352                                            Zaandam    68.750000
# 353            Zaandam - Amsterdam Singelgracht Aansl.          NaN
# 354                     Zaandam - Amsterdam Sloterdijk    99.600000
# 355                                    Zaandam - Hoorn   140.000000
# 356                   Zelzate (B) - Sas van Gent Grens          NaN
# 357                                           Zevenaar    89.750000
# 358                          Zevenaar - Zevenaar Grens    97.857143
# 359                                               Zuid          NaN
# 360                                          Zuidbroek          NaN
# 361                     Zuidbroek - Nieuweschans Grens    65.000000
# 362                                            Zutphen    89.259259
# 363                                 Zutphen - Deventer    60.666667
# 364                                  Zutphen - Hengelo   104.714286
# 365                              Zutphen - Winterswijk   107.960000
# 366                           Zwijndrecht Groote Lindt          NaN
# 367                                             Zwolle    75.500000
# 368                             Zwolle - Herfte Aansl.          NaN
# 369                                    Zwolle - Kampen   215.000000
# 370                                Zwolle - Roosendaal          NaN
# 371                                   Zwolle - Wierden   111.300000
# 372                   Zwolle Industrieterrein Katwolde          NaN
# 373                              Zwolle Lijnwerkplaats          NaN
# 374                              Zwolle Rangeerterrein   110.000000
# 375                                    s Hertogenbosch    89.789474
# 376                         s Hertogenbosch - Nijmegen    87.500000
# 377                     s Hertogenbosch - Vught Aansl.          NaN
# 378                      s Hertogenbosch Gem. Stamlijn          NaN

# %%
# join de Contractgebiedcodes
cg = pd.read_excel('Contractgebiedcodes.xlsx') 
cg = cg.rename(columns={'Code': 'stm_contractgeb_gst'})
df = df.merge(cg, on = 'stm_contractgeb_gst', how = 'outer')

# %%
# outlier verwijderen en de mean van fh_duur berekenen voor eelke Traject  
mean_Contractgebied_df = column_outlier('a', df.copy(), ['stm_fh_duur'])[['stm_fh_duur', 'Contractgebied']].groupby('Contractgebied', as_index = False).mean()

#Plot de data
x = 'stm_fh_duur'
y = 'Contractgebied'

tplot = mean_Contractgebied_df[['stm_fh_duur','Contractgebied']]
tplot.sort_values(['stm_fh_duur'], ascending=True, inplace=True)
tplot.dropna(inplace=True)

tplot.plot(x=x, y=y, kind='scatter',figsize=(10,10))
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='stm_fh_duur', ylabel='Contractgebied'>

# %%
# join de techniekvelden
tgv_df = pd.read_csv('techniekvelden.csv', sep = ';')
tgv_df = tgv_df.rename(columns={'Letter': 'stm_techn_mld'})
df = df.merge(tgv_df, on = 'stm_techn_mld', how = 'outer')
